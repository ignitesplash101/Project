# %% [markdown]
# # 02 – Hedonic Indices (Final Workflow)
#
# This lightweight notebook wraps the production hedonic pipeline inside inal_code.
# Run the cell below to regenerate all hedonic CSVs under inal_code/data/.

# %%
from final_code.hedonic_indices import generate_hedonic_tables
tables = generate_hedonic_tables(save=True)
list(tables.keys())

# %%
tables['ward_full'].head()
